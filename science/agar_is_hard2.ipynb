# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

from skimage import io, exposure, transform, color

# %%
from sklearn import cluster

# %%
image=io.imread('img/agar1.jpg')

# %%
m, n, d = image.shape

# %% [markdown]
# #### Formatting Feature Vector for Color Space Clustering

# %%
X = image.reshape((m*n, d))

# %% [markdown]
# #### Clustering Segmentation

# %%
kmeans = cluster.MiniBatchKMeans(2, batch_size=len(X)/500) # batch_size is arbitrary, read more at sklearn.cluster.MiniBatchKMeans

# %%
y = kmeans.fit(X).labels_

# %%
segmented_image = y.reshape((m, n))

# %%
np.where(segmented_image < .5, False, True)
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]], dtype=bool)

# %%
# np.save('agar_is_not_too_bad', segmented_image)

# %%
fig, ax = plt.subplots(1, 2, figsize=(15,15))
ax[0].imshow(image)
ax[1].imshow(segmented_image)
plt.show()

# %%
io.imsave?

# %%
io.imsave('agar_is_hard_gray.jpg', color.rgb2gray(segmented_image))

# %%
np.linspace(0.2, 1.0, 5)
# Out:
# array([ 0.2,  0.4,  0.6,  0.8,  1. ])

# %%
image = color.rgb2gray(segmented_image)
org = [image]

scale_ims = [transform.resize(segmented_image, (int(s*m),int(s*n))) for s in np.linspace(.2, 1.0, 5)]

ims = org + scale_ims

fig, axes = plt.subplots(len(ims),1,figsize=(15, 15*len(ims)))

for a, im in zip(axes, ims):
    a.imshow(im)
    
plt.show()

# %% [markdown]
# #### Spatial and Color Cluster Segmentation

# %%
from skimage import segmentation

# %%
seg_slic = segmentation.slic(image)
# Out:
# c:\Users\louiery\AppData\Local\Continuum\Anaconda\lib\site-packages\skimage\segmentation\slic_superpixels.py:96: UserWarning: Default value of keyword `sigma` changed from ``1`` to ``0``.
#   warnings.warn('Default value of keyword `sigma` changed from ``1`` '
# c:\Users\louiery\AppData\Local\Continuum\Anaconda\lib\site-packages\skimage\segmentation\slic_superpixels.py:144: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   segments_z = grid_z[slices]
# c:\Users\louiery\AppData\Local\Continuum\Anaconda\lib\site-packages\skimage\segmentation\slic_superpixels.py:144: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   segments_z = grid_z[slices]
# c:\Users\louiery\AppData\Local\Continuum\Anaconda\lib\site-packages\skimage\segmentation\slic_superpixels.py:144: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# ...
